# %%
import pandas as pd

books = pd.read_csv('books_with_categories.csv')

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5197 rows x 14 columns]

# %%
from transformers import pipeline
classifier = pipeline(
    "text-classification",
    model="j-hartmann/emotion-english-distilroberta-base",
    top_k=None,
    device=-1,
    trust_remote_code=True,
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cpu

# %%
classifier("i love this!")
# Out:
# [[{'label': 'joy', 'score': 0.9878191947937012},
#   {'label': 'surprise', 'score': 0.00482978904619813},
#   {'label': 'sadness', 'score': 0.003364608623087406},
#   {'label': 'anger', 'score': 0.0016974426107481122},
#   {'label': 'neutral', 'score': 0.0014085861621424556},
#   {'label': 'fear', 'score': 0.0004598214291036129},
#   {'label': 'disgust', 'score': 0.00042061315616592765}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.654841423034668},
#   {'label': 'neutral', 'score': 0.16985194385051727},
#   {'label': 'sadness', 'score': 0.1164088025689125},
#   {'label': 'surprise', 'score': 0.020700586959719658},
#   {'label': 'disgust', 'score': 0.019100725650787354},
#   {'label': 'joy', 'score': 0.015161293558776379},
#   {'label': 'anger', 'score': 0.003935151733458042}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296027541160583},
#   {'label': 'neutral', 'score': 0.14038576185703278},
#   {'label': 'fear', 'score': 0.06816209107637405},
#   {'label': 'joy', 'score': 0.04794240742921829},
#   {'label': 'anger', 'score': 0.00915635284036398},
#   {'label': 'disgust', 'score': 0.0026284719351679087},
#   {'label': 'sadness', 'score': 0.0021221607457846403}],
#  [{'label': 'neutral', 'score': 0.449370414018631},
#   {'label': 'disgust', 'score': 0.27359241247177124},
#   {'label': 'joy', 'score': 0.10908260941505432},
#   {'label': 'sadness', 'score': 0.09362703561782837},
#   {'label': 'anger', 'score': 0.040478307753801346},
#   {'label': 'surprise', 'score': 0.02697017230093479},
#   {'label': 'fear', 'score': 0.006879065651446581}],
#  [{'label': 'neutral', 'score': 0.6462168097496033},
#   {'label': 'sadness', 'score': 0.2427326887845993},
#   {'label': 'disgust', 'score': 0.04342268034815788},
#   {'label': 'surprise', 'score': 0.028300466015934944},
#   {'label': 'joy', 'score': 0.014211482368409634},
#   {'label': 'fear', 'score': 0.014084089547395706},
#   {'label': 'anger', 'score': 0.011031883768737316}],
#  [{'label': 'fear', 'score': 0.928168535232544},
#   {'label': 'anger', 'score': 0.0321907103061676},
#   {'label': 'neutral', 'score': 0.012808633036911488},
#   {'label': 'sadness', 'score': 0.00875683594495058},
#   {'label': 'surprise', 'score': 0.008597894571721554},
#   {'label': 'disgust', 'score': 0.008431794121861458},
#   {'label': 'joy', 'score': 0.0010455806041136384}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480592768639326},
#   {'label': 'fear', 'score': 0.005393994972109795},
#   {'label': 'surprise', 'score': 0.0022869433742016554},
#   {'label': 'anger', 'score': 0.0018428886542096734},
#   {'label': 'joy', 'score': 0.001733880490064621}],
#  [{'label': 'joy', 'score': 0.9327982664108276},
#   {'label': 'disgust', 'score': 0.03771686181426048},
#   {'label': 'neutral', 'score': 0.015891842544078827},
#   {'label': 'sadness', 'score': 0.006444473285228014},
#   {'label': 'anger', 'score': 0.005024951882660389},
#   {'label': 'surprise', 'score': 0.0015812074998393655},
#   {'label': 'fear', 'score': 0.0005423047696240246}],
#  [{'label': 'joy', 'score': 0.6528704166412354},
#   {'label': 'neutral', 'score': 0.254274845123291},
#   {'label': 'surprise', 'score': 0.06808319687843323},
#   {'label': 'sadness', 'score': 0.009908993728458881},
#   {'label': 'disgust', 'score': 0.00651219068095088},
#   {'label': 'anger', 'score': 0.004821313079446554},
#   {'label': 'fear', 'score': 0.003529015462845564}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169015616178513},
#   {'label': 'disgust', 'score': 0.10400672256946564},
#   {'label': 'surprise', 'score': 0.07876548916101456},
#   {'label': 'anger', 'score': 0.06413363665342331},
#   {'label': 'fear', 'score': 0.05136279761791229},
#   {'label': 'joy', 'score': 0.040564414113759995}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296027541160583},
#  {'label': 'neutral', 'score': 0.14038576185703278},
#  {'label': 'fear', 'score': 0.06816209107637405},
#  {'label': 'joy', 'score': 0.04794240742921829},
#  {'label': 'anger', 'score': 0.00915635284036398},
#  {'label': 'disgust', 'score': 0.0026284719351679087},
#  {'label': 'sadness', 'score': 0.0021221607457846403}]

# %%
sentences[4]
# Out:
# ' He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption'

# %%
predictions[4]
# Out:
# [{'label': 'sadness', 'score': 0.9671575427055359},
#  {'label': 'neutral', 'score': 0.015104170888662338},
#  {'label': 'disgust', 'score': 0.006480592768639326},
#  {'label': 'fear', 'score': 0.005393994972109795},
#  {'label': 'surprise', 'score': 0.0022869433742016554},
#  {'label': 'anger', 'score': 0.0018428886542096734},
#  {'label': 'joy', 'score': 0.001733880490064621}]

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296027541160583},
#   {'label': 'neutral', 'score': 0.14038576185703278},
#   {'label': 'fear', 'score': 0.06816209107637405},
#   {'label': 'joy', 'score': 0.04794240742921829},
#   {'label': 'anger', 'score': 0.00915635284036398},
#   {'label': 'disgust', 'score': 0.0026284719351679087},
#   {'label': 'sadness', 'score': 0.0021221607457846403}],
#  [{'label': 'neutral', 'score': 0.449370414018631},
#   {'label': 'disgust', 'score': 0.27359241247177124},
#   {'label': 'joy', 'score': 0.10908260941505432},
#   {'label': 'sadness', 'score': 0.09362703561782837},
#   {'label': 'anger', 'score': 0.040478307753801346},
#   {'label': 'surprise', 'score': 0.02697017230093479},
#   {'label': 'fear', 'score': 0.006879065651446581}],
#  [{'label': 'neutral', 'score': 0.6462168097496033},
#   {'label': 'sadness', 'score': 0.2427326887845993},
#   {'label': 'disgust', 'score': 0.04342268034815788},
#   {'label': 'surprise', 'score': 0.028300466015934944},
#   {'label': 'joy', 'score': 0.014211482368409634},
#   {'label': 'fear', 'score': 0.014084089547395706},
#   {'label': 'anger', 'score': 0.011031883768737316}],
#  [{'label': 'fear', 'score': 0.928168535232544},
#   {'label': 'anger', 'score': 0.0321907103061676},
#   {'label': 'neutral', 'score': 0.012808633036911488},
#   {'label': 'sadness', 'score': 0.00875683594495058},
#   {'label': 'surprise', 'score': 0.008597894571721554},
#   {'label': 'disgust', 'score': 0.008431794121861458},
#   {'label': 'joy', 'score': 0.0010455806041136384}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480592768639326},
#   {'label': 'fear', 'score': 0.005393994972109795},
#   {'label': 'surprise', 'score': 0.0022869433742016554},
#   {'label': 'anger', 'score': 0.0018428886542096734},
#   {'label': 'joy', 'score': 0.001733880490064621}],
#  [{'label': 'joy', 'score': 0.9327982664108276},
#   {'label': 'disgust', 'score': 0.03771686181426048},
#   {'label': 'neutral', 'score': 0.015891842544078827},
#   {'label': 'sadness', 'score': 0.006444473285228014},
#   {'label': 'anger', 'score': 0.005024951882660389},
#   {'label': 'surprise', 'score': 0.0015812074998393655},
#   {'label': 'fear', 'score': 0.0005423047696240246}],
#  [{'label': 'joy', 'score': 0.6528704166412354},
#   {'label': 'neutral', 'score': 0.254274845123291},
#   {'label': 'surprise', 'score': 0.06808319687843323},
#   {'label': 'sadness', 'score': 0.009908993728458881},
#   {'label': 'disgust', 'score': 0.00651219068095088},
#   {'label': 'anger', 'score': 0.004821313079446554},
#   {'label': 'fear', 'score': 0.003529015462845564}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169015616178513},
#   {'label': 'disgust', 'score': 0.10400672256946564},
#   {'label': 'surprise', 'score': 0.07876548916101456},
#   {'label': 'anger', 'score': 0.06413363665342331},
#   {'label': 'fear', 'score': 0.05136279761791229},
#   {'label': 'joy', 'score': 0.040564414113759995}]]

# %%
sorted(predictions[0], key=lambda x: x['label'])
# Out:
# [{'label': 'anger', 'score': 0.00915635284036398},
#  {'label': 'disgust', 'score': 0.0026284719351679087},
#  {'label': 'fear', 'score': 0.06816209107637405},
#  {'label': 'joy', 'score': 0.04794240742921829},
#  {'label': 'neutral', 'score': 0.14038576185703278},
#  {'label': 'sadness', 'score': 0.0021221607457846403},
#  {'label': 'surprise', 'score': 0.7296027541160583}]

# %%
import numpy as np
emotion_labels = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_prediction = sorted(prediction, key=lambda x: x['label'])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_prediction[index]['score'])
        return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores= calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.00915635284036398),
#   np.float64(0.005966844502836466),
#   np.float64(0.04130087420344353),
#   np.float64(0.016036177054047585),
#   np.float64(0.013624361716210842),
#   np.float64(0.009158502332866192),
#   np.float64(0.003973888698965311),
#   np.float64(0.023656237870454788),
#   np.float64(0.30066895484924316),
#   np.float64(0.017658408731222153)],
#  'disgust': [np.float64(0.0026284719351679087),
#   np.float64(0.0028870662208646536),
#   np.float64(0.024568378925323486),
#   np.float64(0.06069502979516983),
#   np.float64(0.12224263697862625),
#   np.float64(0.012228705920279026),
#   np.float64(0.003816465148702264),
#   np.float64(0.009091978892683983),
#   np.float64(0.27948135137557983),
#   np.float64(0.17792735993862152)],
#  'fear': [np.float64(0.06816209107637405),
#   np.float64(0.0038098806980997324),
#   np.float64(0.10406126081943512),
#   np.float64(0.0016916330205276608),
#   np.float64(0.0950433686375618),
#   np.float64(0.03679516911506653),
#   np.float64(0.0012676806654781103),
#   np.float64(0.40449780225753784),
#   np.float64(0.08446543663740158),
#   np.float64(0.049457043409347534)],
#  'joy': [np.float64(0.04794240742921829),
#   np.float64(0.7044215202331543),
#   np.float64(0.7672374844551086),
#   np.float64(0.16175702214241028),
#   np.float64(0.008335662074387074),
#   np.float64(0.04337584972381592),
#   np.float64(0.8725652098655701),
#   np.float64(0.013375142589211464),
#   np.float64(0.001390498480759561),
#   np.float64(0.03219766169786453)],
#  'neutral': [np.float64(0.14038576185703278),
#   np.float64(0.21776005625724792),
#   np.float64(0.04217596352100372),
#   np.float64(0.732685387134552),
#   np.float64(0.27261361479759216),
#   np.float64(0.621392548084259),
#   np.float64(0.07678419351577759),
#   np.float64(0.29216551780700684),
#   np.float64(0.029392074793577194),
#   np.float64(0.6624059081077576)],
#  'sadness': [np.float64(0.0021221607457846403),
#   np.float64(0.004508520942181349),
#   np.float64(0.01085986103862524),
#   np.float64(0.02098814956843853),
#   np.float64(0.47588053345680237),
#   np.float64(0.005146408453583717),
#   np.float64(0.004653005860745907),
#   np.float64(0.022726496681571007),
#   np.float64(0.23277661204338074),
#   np.float64(0.013540085405111313)],
#  'surprise': [np.float64(0.7296027541160583),
#   np.float64(0.060646045953035355),
#   np.float64(0.009796065278351307),
#   np.float64(0.006146552041172981),
#   np.float64(0.012259824201464653),
#   np.float64(0.27190282940864563),
#   np.float64(0.03693943843245506),
#   np.float64(0.23448683321475983),
#   np.float64(0.07182509452104568),
#   np.float64(0.046813491731882095)]}

# %%
from tqdm import tqdm 
emotion_labels = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores= calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [08:15<00:00, 10.48it/s]

# %%
emotion_scores_df = pd.DataFrame(emotion_scores)
emotion_scores_df["isbn13"] = isbn

# %%
emotion_scores_df
# Out:
#          anger   disgust      fear       joy   neutral   sadness  surprise  \
# 0     0.009156  0.002628  0.068162  0.047942  0.140386  0.002122  0.729603
# 1     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 2     0.041301  0.024568  0.104061  0.767237  0.042176  0.010860  0.009796
# 3     0.016036  0.060695  0.001692  0.161757  0.732685  0.020988  0.006147
# 4     0.013624  0.122243  0.095043  0.008336  0.272614  0.475881  0.012260
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.025156  0.001939  0.094667  0.002254  0.010511  0.857255  0.008218
# 5193  0.005602  0.003775  0.018216  0.400263  0.338892  0.005487  0.227765
# 5194  0.008463  0.009147  0.013295  0.620453  0.329753  0.010788  0.008101
# 5195  0.005475  0.034545  0.003970  0.258353  0.648011  0.017372  0.032275
# 5196  0.002837  0.003137  0.001166  0.958549  0.028252  0.002916  0.003142
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotion_scores_df, on="isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   neutral   sadness  surprise
# 0     0.009156  0.002628  0.068162  0.047942  0.140386  0.002122  0.729603
# 1     0.005967  0.002887  0.003810  0.704422  0.217760  0.004509  0.060646
# 2     0.041301  0.024568  0.104061  0.767237  0.042176  0.010860  0.009796
# 3     0.016036  0.060695  0.001692  0.161757  0.732685  0.020988  0.006147
# 4     0.013624  0.122243  0.095043  0.008336  0.272614  0.475881  0.012260
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.025156  0.001939  0.094667  0.002254  0.010511  0.857255  0.008218
# 5193  0.005602  0.003775  0.018216  0.400263  0.338892  0.005487  0.227765
# 5194  0.008463  0.009147  0.013295  0.620453  0.329753  0.010788  0.008101
# 5195  0.005475  0.034545  0.003970  0.258353  0.648011  0.017372  0.032275
# 5196  0.002837  0.003137  0.001166  0.958549  0.028252  0.002916  0.003142
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index=False)
